# %% [markdown]
# # Project: Prediction of conclave result
#
# Started: 18-01-2020
# Authors: Jakub Kozlowski, Szymon Klepacki
#
# ---

# %% [markdown]
# ## 1. Get data about past conclaves
# Data for the project was scraped from Wikipedia's articles about past conclaves and currently living cardinals.

# %%
import pandas as pd
import numpy as np
from dateutil.relativedelta import relativedelta

# %%
col_names = ['Name', 'Country', 'Title', 'Title2', 'Date_of_birth', 'Date_of_election']

# %%
url_1922 = "https://it.wikipedia.org/wiki/Conclave_del_1922"
participants_1922 = pd.read_html(url_1922, parse_dates = True)[2]
participants_1922 = participants_1922[participants_1922.index.isin(participants_1922.index[1:])]
participants_1922.columns = col_names
participants_1922['Date'] = pd.to_datetime('02/02/1922', format = '%d/%m/%Y')

# %%
def select_new_pope(data):
    """
    Function applying '1' to the cardinal elected pope during a conclave
    
    :param x: str
    :return: 
    
    """
    data1 = data
    
    data1['Elected'] = data1['Name'].apply(lambda x: 1 if x[-13:] == '(eletto papa)' else 0)
    data1['Name'] = data1['Name'].apply(lambda x: x[:-14] if x[-13:] == '(eletto papa)' else x)

    return data1
    
select_new_pope(participants_1922)
# Out:
#                                        Name                Country  \
# 1                       Karl Joseph Schulte   Repubblica di Weimar
# 2                             Edmund Dalbor  Repubblica di Polonia
# 3                     Michael von Faulhaber   Repubblica di Weimar
# 4       Francisco de Asís Vidal y Barraquer        Regno di Spagna
# 5            Rafael Merry del Val y Zulueta        Regno di Spagna
# 6                      Juan Benlloch y Vivó        Regno di Spagna
# 7                    Friedrich Gustav Piffl   Repubblica Austriaca
# 8                   Giovanni Tacci Porcelli                 Italia
# 9                      Tommaso Pio Boggiani                 Italia
# 10                      Aleksander Kakowski  Repubblica di Polonia
# 11                         Camillo Laurenti                 Italia
# 12                 Francis Alphonsus Bourne            Regno Unito
# 13                       Pietro La Fontaine                 Italia
# 14                             Michele Lega                 Italia
# 15                            Adolf Bertram   Repubblica di Weimar
# 16                      Louis-Joseph Maurin                Francia
# 17                             Pietro Maffi                 Italia
# 18                        Alessandro Lualdi                 Italia
# 19          Raffaele Scapinelli di Leguigno                 Italia
# 20                          Basilio Pompilj                 Italia
# 21      Vittorio Amedeo Ranuzzi de' Bianchi                 Italia
# 22                            Achille Ratti                 Italia
# 23          Donato Raffaele Sbarretti Tazza                 Italia
# 24                      Louis-Ernest Dubois                Francia
# 25                            Oreste Giorgi                 Italia
# 26                          Gaetano Bisleti                 Italia
# 27                Willem Marinus van Rossum            Paesi Bassi
# 28                  Teodoro Valfrè di Bonzo                 Italia
# 29                           Gaetano De Lai                 Italia
# 30                           János Csernoch       Regno d'Ungheria
# 31                          Pietro Gasparri                 Italia
# 32                Alfonso Maria Mistrangelo                 Italia
# 33  Desiré-Félicien-François-Joseph Mercier                 Belgio
# 34   Gennaro Granito Pignatelli di Belmonte                 Italia
# 35                       Francesco Ragonesi                 Italia
# 36                        Agostino Richelmy                 Italia
# 37                    Pierre-Paulin Andrieu                Francia
# 38                             Antonio Vico                 Italia
# 39                    Francis Aidan Gasquet            Regno Unito
# 40        Giuseppe Francica-Nava de Bondifè                 Italia
# 41                             Augusto Silj                 Italia
# 42                             Louis Billot                Francia
# 43               Ottavio Cagiano de Azevedo                 Italia
participants_1939 = pd.read_html(url_1939, parse_dates = True)[2]
participants_1939 = participants_1939[participants_1939.index.isin(participants_1939.index[1:])]
participants_1939.columns = col_names
participants_1939['Date'] = pd.to_datetime('01/03/1939', format = '%d/%m/%Y')
select_new_pope(participants_1939)
# Out:
#                                       Name   Country  \
# 1                 Adeodato Giovanni Piazza    Italia
# 2                 Jusztinián György Serédi  Ungheria
# 3                         Eugène Tisserant   Francia
# 4                          Achille Liénart   Francia
# 5           Jean-Marie-Rodrigue Villeneuve    Canada
# ..                                     ...       ...
# 57                           Adolf Bertram  Germania
# 58          Alfred-Henri-Marie Baudrillart   Francia
# 59         Donato Raffaele Sbarretti Tazza    Italia
# 60                Federico Cattani Amadori    Italia
# 61  Gennaro Granito Pignatelli di Belmonte    Italia
#
#                                                 Title  \
# 1                Cardinale presbitero di Santa Prisca
# 2   Cardinale presbitero dei Santi Andrea e Gregor...
# 3   Cardinale presbitero dei Santi Vito, Modesto e...
# 4                   Cardinale presbitero di San Sisto
# 5    Cardinale presbitero di Santa Maria degli Angeli
# ..                                                ...
# 57  Cardinale presbitero di Sant'Agnese fuori le mura
# 58  Cardinale presbitero di San Bernardo alle Term...
# 59       Cardinale vescovo di Sabina e Poggio Mirteto
# 60         Cardinale diacono di Santa Maria in Aquiro
# 61  Cardinale vescovo di Ostia; Cardinale vescovo ...
#
#                                                Title2 Date_of_birth  \
# 1                                Patriarca di Venezia    20/09/1884
# 2                Arcivescovo metropolita di Strigonio    23/04/1884
# 3   Segretario della Congregazione per le Chiese O...    24/03/1884
# 4                                    Vescovo di Lilla    07/02/1884
# 5                   Arcivescovo metropolita di Québec    02/11/1883
# ..                                                ...           ...
# 57               Arcivescovo metropolita di Breslavia    14/03/1859
# 58  Rettore dell'Istituto Cattolico di Parigi; Ves...    06/01/1859
# 59  Sottodecano del Collegio Cardinalizio; Segreta...    12/11/1856
# 60  Segretario emerito del Supremo Tribunale della...    17/04/1856
# 61  Decano del Collegio Cardinalizio; Prefetto del...    10/04/1851
#
#    Date_of_election       Date  Elected
# 1        13/12/1937 1939-03-01        0
# 2        19/12/1927 1939-03-01        0
# 3        15/06/1936 1939-03-01        0
# 4        30/06/1930 1939-03-01        0
# 5        13/03/1933 1939-03-01        0
# ..              ...        ...      ...
# 57       04/12/1916 1939-03-01        0
# 58       16/12/1935 1939-03-01        0
# 59       04/12/1916 1939-03-01        0
# 60       16/12/1935 1939-03-01        0
# 61       27/11/1911 1939-03-01        0
#
# [61 rows x 8 columns]

# %%
participants_1939.head()
# Out:
#                              Name   Country  \
# 1        Adeodato Giovanni Piazza    Italia
# 2        Jusztinián György Serédi  Ungheria
# 3                Eugène Tisserant   Francia
# 4                 Achille Liénart   Francia
# 5  Jean-Marie-Rodrigue Villeneuve    Canada
#
#                                                Title  \
# 1               Cardinale presbitero di Santa Prisca
# 2  Cardinale presbitero dei Santi Andrea e Gregor...
# 3  Cardinale presbitero dei Santi Vito, Modesto e...
# 4                  Cardinale presbitero di San Sisto
# 5   Cardinale presbitero di Santa Maria degli Angeli
#
#                                               Title2 Date_of_birth  \
# 1                               Patriarca di Venezia    20/09/1884
# 2               Arcivescovo metropolita di Strigonio    23/04/1884
# 3  Segretario della Congregazione per le Chiese O...    24/03/1884
# 4                                   Vescovo di Lilla    07/02/1884
# 5                  Arcivescovo metropolita di Québec    02/11/1883
#
#   Date_of_election       Date  Elected
# 1       13/12/1937 1939-03-01        0
# 2       19/12/1927 1939-03-01        0
# 3       15/06/1936 1939-03-01        0
# 4       30/06/1930 1939-03-01        0
# 5       13/03/1933 1939-03-01        0

# %%
url_1958 = "https://it.wikipedia.org/wiki/Conclave_del_1958"
participants_1958 = pd.read_html(url_1958, parse_dates = True)[2]
participants_1958 = participants_1958[participants_1958.index.isin(participants_1958.index[1:])]
participants_1958.columns = col_names
participants_1958['Date'] = pd.to_datetime('25/10/1958', format = '%d/%m/%Y')
select_new_pope(participants_1958)
# Out:
#                                     Name             Country  \
# 1                       Paul-Émile Léger              Canada
# 2                       Stefan Wyszyński             Polonia
# 3                          Joseph Wendel      Germania Ovest
# 4                       Valerian Gracias               India
# 5            Fernando Quiroga y Palacios              Spagna
# 6                   Norman Thomas Gilroy           Australia
# 7           Krikor Bedros XV Aghagianian              Libano
# 8                 James Charles McGuigan              Canada
# 9                 Jaime de Barros Câmara             Brasile
# 10                       Giacomo Lercaro              Italia
# 11                     Alfredo Ottaviani              Italia
# 12                   Thomas Tien Ken-sin  Repubblica di Cina
# 13   Carlos Carmelo de Vasconcelos Motta             Brasile
# 14               Francis Joseph Spellman         Stati Uniti
# 15          Teodósio Clemente de Gouveia          Portogallo
# 16                Crisanto Luque Sánchez            Colombia
# 17                      Antonio Caggiano           Argentina
# 18            Manuel Gonçalves Cerejeira          Portogallo
# 19                       Ernesto Ruffini              Italia
# 20                          Josef Frings      Germania Ovest
# 21          James Francis Louis McIntyre         Stati Uniti
# 22           Benjamín de Arriba y Castro              Spagna
# 23                        Pietro Ciriaci              Italia
# 24                      Eugène Tisserant             Francia
# 25                       Achille Liénart             Francia
# 26                        Valerio Valeri              Italia
# 27                        Maurice Feltin             Francia
# 28                  John Francis D'Alton             Irlanda
# 29                        Marcello Mimmi              Italia
# 30                     Gaetano Cicognani              Italia
# 31              Angelo Giuseppe Roncalli              Italia
# 32                  Clément-Emile Roques             Francia
# 33                  Pierre-Marie Gerlier             Francia
# 34                 Santiago Luis Copello           Argentina
# 35           Manuel Arteaga y Betancourt                Cuba
# 36                       Clemente Micara              Italia
# 37           Ignazio Gabriele I Tappouni              Libano
# 38              Benedetto Aloisi Masella              Italia
# 39                     Giuseppe Pizzardo              Italia
# 40                  Enrique Pla y Deniel              Spagna
# 41                      Maurilio Fossati              Italia
# 42               Augusto Álvaro da Silva             Brasile
# 43                         Nicola Canali              Italia
# 44                 Jozef-Ernest van Roey              Belgio
# 45       Carlos María Javier de la Torre             Ecuador
# 46                   Federico Tedeschini              Italia
# 47                Pietro Fumasoni Biondi              Italia
# 48                      Elia Dalla Costa              Italia
# 49  Georges-François-Xavier-Marie Grente             Francia
# 50             José María Caro Rodríguez                Cile
#
#                                                 Title  \
# 1    Cardinale presbitero di Santa Maria degli Angeli
# 2   Cardinale presbitero di Santa Maria in Trastevere
# 3           Cardinale presbitero di Santa Maria Nuova
# 20       18/02/1946 1958-10-25        0
# 21       12/01/1953 1958-10-25        0
# 22       12/01/1953 1958-10-25        0
# 23       12/01/1953 1958-10-25        0
# 24       15/06/1936 1958-10-25        0
# 25       30/06/1930 1958-10-25        0
# 26       12/01/1953 1958-10-25        0
# 27       12/01/1953 1958-10-25        0
# 28       12/01/1953 1958-10-25        0
# 29       12/01/1953 1958-10-25        0
# 30       12/01/1953 1958-10-25        0
# 31       12/01/1953 1958-10-25        1
# 32       18/02/1946 1958-10-25        0
# 33       13/12/1937 1958-10-25        0
# 34       16/12/1935 1958-10-25        0
# 35       18/02/1946 1958-10-25        0
# 36       18/02/1946 1958-10-25        0
# 37       16/12/1935 1958-10-25        0
# 38       18/02/1946 1958-10-25        0
# 39       13/12/1937 1958-10-25        0
# 40       18/02/1946 1958-10-25        0
# 41       13/03/1933 1958-10-25        0
# 42       12/01/1953 1958-10-25        0
# 43       16/12/1935 1958-10-25        0
# 44       20/06/1927 1958-10-25        0
# 45       12/01/1953 1958-10-25        0
# 46       13/03/1933 1958-10-25        0
# 47       13/03/1933 1958-10-25        0
# 48       13/03/1933 1958-10-25        0
# 49       12/01/1953 1958-10-25        0
# 50       18/02/1946 1958-10-25        0

# %%
participants_1958.head()
# Out:
#                           Name         Country  \
# 1             Paul-Émile Léger          Canada
# 2             Stefan Wyszyński         Polonia
# 3                Joseph Wendel  Germania Ovest
# 4             Valerian Gracias           India
# 5  Fernando Quiroga y Palacios          Spagna
#
#                                                Title  \
# 1   Cardinale presbitero di Santa Maria degli Angeli
# 2  Cardinale presbitero di Santa Maria in Trastevere
# 3          Cardinale presbitero di Santa Maria Nuova
# 4    Cardinale presbitero di Santa Maria in Via Lata
# 5              Cardinale presbitero di Sant'Agostino
#
#                                               Title2 Date_of_birth  \
# 1                Arcivescovo metropolita di Montréal    26/04/1904
# 2  Arcivescovo metropolita di Gniezno; Arcivescov...    03/08/1901
# 3  Arcivescovo metropolita di Monaco e Frisinga; ...    27/05/1901
# 4                  Arcivescovo metropolita di Bombay    23/10/1900
# 5  Arcivescovo metropolita di Santiago di Compostela    21/01/1900
#
#   Date_of_election       Date  Elected
# 1       12/01/1953 1958-10-25        0
# 2       12/01/1953 1958-10-25        0
# 3       12/01/1953 1958-10-25        0
# 4       12/01/1953 1958-10-25        0
# 5       12/01/1953 1958-10-25        0

# %%
url_1963 = "https://it.wikipedia.org/wiki/Conclave_del_1963"
participants_1963 = pd.read_html(url_1963, parse_dates = True)[2]
participants_1963 = participants_1963[participants_1963.index.isin(participants_1963.index[1:])]
participants_1963.columns = col_names
participants_1963['Date'] = pd.to_datetime('19/06/1963', format = '%d/%m/%Y')
participants_1963['Elected'] = participants_1963['Name'].apply(lambda x: 1 if x == 'Giovanni Battista Montini' else 0)

# %%
url_1978_2 = "https://it.wikipedia.org/wiki/Conclave_dell%27ottobre_1978"
participants_1978_2 = pd.read_html(url_1978_2, parse_dates = True)[3]
participants_1978_2 = participants_1978_2[participants_1978_2.index.isin(participants_1978_2.index[1:])]
participants_1978_2.columns = col_names
participants_1978_1 = participants_1978_2
participants_1978_2['Date'] = pd.to_datetime('14/10/1978', format = '%d/%m/%Y')
participants_1978_2['Elected'] = participants_1978_2['Name'].apply(lambda x: 1 if x == 'Karol Wojtyła' else 0)

# %%
luciani_in = pd.DataFrame([{'Name': 'Albino Luciani', 
                            'Country': 'Italia', 
                            'Title': 'Cardinale presbitero di San Marco', 
                            'Title2': 'Patriarca di Venezia', 
                            'Date_of_birth': '17/10/1912',
                            'Date_of_election': '05/03/1973',
                            'Date': pd.to_datetime('25/08/1978'),
                            'Elected': 1}])

# %%
participants_1978_1 = pd.concat([participants_1978_1.loc[participants_1978_1.Name != 'John Joseph Wright', :],
                                 luciani_in]).sort_index()

# %%
participants_1978_1['Date'] =  pd.to_datetime('25/08/1978', format = '%d/%m/%Y')

# %%
participants_1978_1['Elected'] = participants_1978_1['Name'].apply(lambda x: 1 if x == 'Albino Luciani' else 0)

# %%
url_2005 = "https://it.wikipedia.org/wiki/Conclave_del_2005"
participants_2005 = pd.read_html(url_2005)[9]
participants_2005 = participants_2005[participants_2005.index.isin(participants_2005.index[1:])]
participants_2005.columns = col_names
participants_2005['Date'] = pd.to_datetime('19/04/2005', format = '%d/%m/%Y')
participants_2005['Elected'] = participants_2005['Name'].apply(lambda x: 1 if x == 'Joseph Ratzinger' else 0)

# %%
url_2013 = "https://it.wikipedia.org/wiki/Conclave_del_2013"
participants_2013 = pd.read_html(url_2013)[2]
participants_2013 = participants_2013[participants_2013.index.isin(participants_2013.index[1:])]
participants_2013.columns = col_names
participants_2013['Date'] = pd.to_datetime('12/03/2013', format = '%d/%m/%Y')
participants_2013['Elected'] = participants_2013['Name'].apply(lambda x: 1 if x == 'Jorge Mario Bergoglio' else 0)

# %%
participants_2013.head()
# Out:
#                   Name      Country  \
# 1   Luis Antonio Tagle    Filippine
# 2  Rainer Maria Woelki     Germania
# 3        Reinhard Marx     Germania
# 4  Willem Jacobus Eijk  Paesi Bassi
# 5           Péter Erdő     Ungheria
#
#                                                Title  \
# 1  Cardinale presbitero di San Felice da Cantalic...
# 2  Cardinale presbitero di San Giovanni Maria Via...
# 3             Cardinale presbitero di San Corbiniano
# 4               Cardinale presbitero di San Callisto
# 5              Cardinale presbitero di Santa Balbina
#
#                               Title2 Date_of_birth Date_of_election  \
# 1              Arcivescovo di Manila    21/06/1957       24/11/2012
# 2             Arcivescovo di Berlino    18/08/1956       18/02/2012
# 3   Arcivescovo di Monaco e Frisinga    21/09/1953       20/11/2010
# 4             Arcivescovo di Utrecht    22/06/1953       18/02/2012
# 5  Arcivescovo di Esztergom-Budapest    25/06/1952       21/10/2003
#
#         Date  Elected
# 1 2013-03-12        0
# 2 2013-03-12        0
# 3 2013-03-12        0
# 4 2013-03-12        0
# 5 2013-03-12        0

# %%
conclave_part_list = [participants_1922, participants_1939, participants_1958, participants_1963, participants_1978_1,
                      participants_1978_2, participants_2005, participants_2013]

# %%
participants = pd.concat(conclave_part_list, axis=0).reset_index(drop=True)
participants.head(2)
# Out:
#                   Name                Country  \
# 0  Karl Joseph Schulte   Repubblica di Weimar
# 1        Edmund Dalbor  Repubblica di Polonia
#
#                                                Title  \
# 0    Cardinale presbitero dei Santi Quattro Coronati
# 1  Cardinale presbitero di San Giovanni a Porta L...
#
#                                         Title2 Date_of_birth Date_of_election  \
# 0           Arcivescovo metropolita di Colonia    14/09/1871       07/03/1921
# 1  Arcivescovo metropolita di Gniezno e Poznań    30/10/1869       15/12/1919
#
#         Date  Elected
# 0 1922-02-02        0
# 1 1922-02-02        0

# %%
participants.to_pickle('Data/conclave_participants_raw.pkl')

# %%
participants['Italian'] = 0
participants.loc[participants.Country == 'Italia', 'Italian'] = 1

# %%
participants.Date_of_birth = pd.to_datetime(participants.Date_of_birth)
participants.Date_of_election = pd.to_datetime(participants.Date_of_election)
participants.head(2)
# Out:
#                   Name                Country  \
# 0  Karl Joseph Schulte   Repubblica di Weimar
# 1        Edmund Dalbor  Repubblica di Polonia
#
#                                                Title  \
# 0    Cardinale presbitero dei Santi Quattro Coronati
# 1  Cardinale presbitero di San Giovanni a Porta L...
#
#                                         Title2 Date_of_birth Date_of_election  \
# 0           Arcivescovo metropolita di Colonia    1871-09-14       1921-07-03
# 1  Arcivescovo metropolita di Gniezno e Poznań    1869-10-30       1919-12-15
#
#         Date  Elected  Italian
# 0 1922-02-02        0        0
# 1 1922-02-02        0        0

# %%
participants['Rank'] = participants.Title.apply(lambda x: 'CP' if x.split()[1] == 'presbitero' else 'CB' if x.split()[1] == 'vescovo' else 'CD')

# %%
participants['Emeritus'] = participants.Title2.apply(lambda x: 1 if x.split()[1] == 'emerito' else 0)

# %%
participants['Office'] = participants.Title2.apply(lambda x: 'Archbishop' if (x.split()[0] == 'Arcivescovo' or x.split()[0] == 'Vescovo' or x.split()[0] == 'Patriarca')else 'Prefect' if x.split()[0] == 'Prefetto' else 'Other_curia')

# %%
participants['Age_at_conclave'] = [relativedelta(a, b).years for a, b in zip(participants['Date'], participants['Date_of_birth'])]

# %%
# ((participants['Date_of_election'] - participants['Date'])/np.timedelta64(1, 'M')).astype(int)

# %%
participants['Card_seniority'] = [12 - relativedelta(a, b).months + relativedelta(a, b).years*12 for a, b in zip(participants['Date'], participants['Date_of_election'])]

# %%
participants1 = participants.copy()
participants1 = participants1.drop(['Country', 'Title', 'Title2', 'Date_of_birth', 'Date_of_election'], 1)

# %%
participants1 = pd.concat([participants1.drop('Office', axis=1),
                           pd.get_dummies(participants1['Office'])], axis=1)
participants1 = pd.concat([participants1.drop('Rank', axis=1),
                           pd.get_dummies(participants1['Rank'])], axis=1)
participants1.head(3)
# Out:
#                     Name       Date  Elected  Italian  Emeritus  \
# 0    Karl Joseph Schulte 1922-02-02        0        0         0
# 1          Edmund Dalbor 1922-02-02        0        0         0
# 2  Michael von Faulhaber 1922-02-02        0        0         0
#
#    Age_at_conclave  Card_seniority  Archbishop  Other_curia  Prefect  CB  CD  \
# 0               50               6           1            0        0   0   0
# 1               52              35           1            0        0   0   0
# 2               52               6           1            0        0   0   0
#
#    CP
# 0   1
# 1   1
# 2   1

# %%
participants1.to_pickle('Data/conclave_participants_features.pkl')

# %% [markdown]
# # 2. Get data about currently living cardinals

# %%
from feature_engineering_utils import del_pope, del_index, delete_latin_encoding

# %%
# Get the list of current cardinals
url_cardinals = "https://en.wikipedia.org/wiki/List_of_living_cardinals"
living_cardinals = pd.read_html(url_cardinals, parse_dates=True)[0]

# Remove cardinals who already are over 80 years old - they are marked with '*'
living_cardinals.drop(living_cardinals[living_cardinals.iloc[:, 1].str.strip().str[-1] == "*"].index, inplace=True)

# Remove not necessary columns
living_cardinals = living_cardinals.drop(['No.', 'Ref.'], axis=1).reset_index(drop=True)

# Obtain date of birth
living_cardinals['Born'] = living_cardinals['Born'].str[:-8]

# Apply deleting popes' names
living_cardinals['Consistory'] = living_cardinals['Consistory'].apply(lambda x: del_pope(x))

# Apply deleting redundant indices
living_cardinals['Consistory'] = living_cardinals['Consistory'].apply(lambda x: del_index(x))

# Apply deleting 'latin' encoding to 'Born', 'Name' and 'Office' variables
# Delete 'latin' encoded spaces from given variable
living_cardinals['Born'] = living_cardinals['Born'].apply(lambda x: delete_latin_encoding(x))
living_cardinals['Name'] = living_cardinals['Name'].apply(lambda x: delete_latin_encoding(x))
living_cardinals['Office'] = living_cardinals['Office'].apply(lambda x: delete_latin_encoding(x))

# Day and month of birth of Archbishop of Nairobi is unknown. hence it was set to 1st January
living_cardinals.loc[living_cardinals['Name'] == 'John Njue', "Born"] = '1 January 1944'

# Convert 'Born' variable to data format
living_cardinals['Born'] = pd.to_datetime(living_cardinals['Born'], format="%d %B %Y")

# Convert 'Consistory' variable to data format
living_cardinals['Consistory'] = pd.to_datetime(living_cardinals['Consistory'], format="%d %B %Y")

# Get dummie variables of cardinals' ranks (Bishop, Priest, Deacon)
living_cardinals = pd.concat([living_cardinals.drop('Order', 1), pd.get_dummies(living_cardinals['Order'])], axis=1)

# Get binary variable - Italian or not
living_cardinals['Italian'] = living_cardinals['Country'].apply(lambda x: 1 if x == 'Italy' else 0)

# Transform 'Office' variable into cardinal's offices: Archbishop, Prefect or Other Vatican curia post
living_cardinals['Office_add'] = living_cardinals['Office'].apply(lambda x: 'Archbishop' if (
            x.split()[0] == 'Archbishop' or x.split()[0] == 'Bishop' or x.split()[0] == 'Patriarch' or x.split()[
        1] == 'Archbishop' or x.split()[1] == 'Bishop') else 'Prefect' if x.split()[
                                                                              0] == 'Prefect' else 'Other_curia')

# Get binary checking whether cardinal is an emeritus
living_cardinals['Emeritus'] = living_cardinals['Office'].apply(lambda x: 1 if x.split()[1] == 'emeritus' else 0)

# Get dummy variables of cardinals offices and drop unnecessary columns
living_cardinals = pd.concat(
    [living_cardinals.drop(['Country', 'Office_add', 'Office'], 1),
     pd.get_dummies(living_cardinals['Office_add'])
     ],
    axis=1)

# %%
living_cardinals.head()
# Out:
#                Name       Born Consistory  CB  CD  CP  Italian  Emeritus  \
# 0   Leonardo Sandri 1943-11-18 2007-11-24   1   0   0        0         0
# 1    Pietro Parolin 1955-01-17 2014-02-22   1   0   0        1         0
# 2  Marc Ouellet PSS 1944-06-08 2003-10-21   1   0   0        0         0
# 3   Fernando Filoni 1946-04-15 2012-02-18   1   0   0        1         0
# 4  Beniamino Stella 1941-08-18 2014-02-22   1   0   0        1         0
#
#    Archbishop  Other_curia  Prefect
# 0           0            0        1
# 1           0            1        0
# 2           0            0        1
# 3           0            1        0
# 4           0            0        1

# %%
living_cardinals.to_pickle('Data/living_participants.pkl')
