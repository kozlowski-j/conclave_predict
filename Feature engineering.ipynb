# %% [markdown]
# Feature engineering beginning

# %%
participants['Italian'] = 0
participants.loc[participants.Country == 'Italia', 'Italian'] = 1

# %%
participants.Date_of_birth = pd.to_datetime(participants.Date_of_birth)
participants.Date_of_election = pd.to_datetime(participants.Date_of_election)
participants
# Out:
#                                     Name                Country  \
# 0                    Karl Joseph Schulte   Repubblica di Weimar
# 1                          Edmund Dalbor  Repubblica di Polonia
# 2                  Michael von Faulhaber   Repubblica di Weimar
# 3    Francisco de Asís Vidal y Barraquer        Regno di Spagna
# 4         Rafael Merry del Val y Zulueta        Regno di Spagna
# ..                                   ...                    ...
# 495      Francisco Javier Errázuriz Ossa                   Cile
# 496                    Godfried Danneels                 Belgio
# 497                Juan Sandoval Íñiguez                Messico
# 498                     Severino Poletto                 Italia
# 499                        Walter Kasper               Germania
#
#                                                  Title  \
# 0      Cardinale presbitero dei Santi Quattro Coronati
# 1    Cardinale presbitero di San Giovanni a Porta L...
# 2               Cardinale presbitero di Sant'Anastasia
# 3                 Cardinale presbitero di Santa Sabina
# 4               Cardinale presbitero di Santa Prassede
# ..                                                 ...
# 495     Cardinale presbitero di Santa Maria della Pace
# 496             Cardinale presbitero di Sant'Anastasia
# 497  Cardinale presbitero di Nostra Signora di Guad...
# 498  Cardinale presbitero di San Giuseppe in Via Tr...
# 499  Cardinale presbitero di Ognissanti in Via Appi...
#
#                                                 Title2 Date_of_birth  \
# 0                   Arcivescovo metropolita di Colonia    1871-09-14
# 1          Arcivescovo metropolita di Gniezno e Poznań    1869-10-30
# 2         Arcivescovo metropolita di Monaco e Frisinga    1869-05-03
# 3                 Arcivescovo metropolita di Tarragona    1868-03-10
# 4    Arciprete della Basilica di San Pietro in Vati...    1865-10-10
# ..                                                 ...           ...
# 495           Arcivescovo emerito di Santiago del Cile    1933-05-09
# 496           Arcivescovo emerito di Malines-Bruxelles    1933-04-06
# 497                 Arcivescovo emerito di Guadalajara    1933-03-28
# 498                      Arcivescovo emerito di Torino    1933-03-18
# 499  Presidente emerito del Pontificio consiglio pe...    1933-05-03
#
#     Date_of_election       Date  Elected  Italian
# 0         1921-07-03 1922-02-02        0        0
# 1         1919-12-15 1922-02-02        0        0
# 2         1921-07-03 1922-02-02        0        0
# 3         1921-07-03 1922-02-02        0        0
# 4         1903-09-11 1922-02-02        0        0
# ..               ...        ...      ...      ...
# 495       2001-02-21 2013-03-12        0        0
# 496       1983-02-02 2013-03-12        0        0
# 497       1994-11-26 2013-03-12        0        0
# 498       2001-02-21 2013-03-12        0        1
# 499       2001-02-21 2013-03-12        0        0
#
# [500 rows x 9 columns]

# %%
participants['Rank'] = participants.Title.apply(lambda x: 'CP' if x.split()[1] == 'presbitero' else 'CB' if x.split()[1] == 'vescovo' else 'CD')

# %%
participants['Emeritus'] = participants.Title2.apply(lambda x: 1 if x.split()[1] == 'emerito' else 0)

# %%
participants['Office'] = participants.Title2.apply(lambda x: 'Archbishop' if (x.split()[0] == 'Arcivescovo' or x.split()[0] == 'Vescovo' or x.split()[0] == 'Patriarca')else 'Prefect' if x.split()[0] == 'Prefetto' else 'Other_curia')

# %%
participants['Age_at_conclave'] = [relativedelta(a, b).years for a, b in zip(participants['Date'], participants['Date_of_birth'])]

# %%
participants['Card_seniority'] = [12 - relativedelta(a, b).months + relativedelta(a, b).years*12 for a, b in zip(participants['Date'], participants['Date_of_election'])]

# %%
participants1 = participants

# %%
participants1 = participants1.drop(['Country', 'Title', 'Title2', 'Date_of_birth', 'Date_of_election', 'Date'], 1)

# %%
participants1 = pd.concat([participants1.drop('Office', axis=1), pd.get_dummies(participants1['Office'])], axis=1)
participants1 = pd.concat([participants1.drop('Rank', axis=1), pd.get_dummies(participants1['Rank'])], axis=1)
participants1
# Out:
#                                     Name  Elected  Italian  Emeritus  \
# 0                    Karl Joseph Schulte        0        0         0
# 1                          Edmund Dalbor        0        0         0
# 2                  Michael von Faulhaber        0        0         0
# 3    Francisco de Asís Vidal y Barraquer        0        0         0
# 4         Rafael Merry del Val y Zulueta        0        0         0
# ..                                   ...      ...      ...       ...
# 495      Francisco Javier Errázuriz Ossa        0        0         1
# 496                    Godfried Danneels        0        0         1
# 497                Juan Sandoval Íñiguez        0        0         1
# 498                     Severino Poletto        0        1         1
# 499                        Walter Kasper        0        0         1
#
#      Age_at_conclave  Card_seniority  Archbishop  Other_curia  Prefect  CB  \
# 0                 50               6           1            0        0   0
# 1                 52              35           1            0        0   0
# 2                 52               6           1            0        0   0
# 3                 53               6           1            0        0   0
# 4                 56             224           0            1        0   0
# ..               ...             ...         ...          ...      ...  ..
# 495               79             156           1            0        0   0
# 496               79             371           1            0        0   0
# 497               79             225           1            0        0   0
# 498               79             156           1            0        0   0
# 499               79             156           0            1        0   0
#
#      CD  CP
# 0     0   1
# 1     0   1
# 2     0   1
# 3     0   1
# 4     0   1
# ..   ..  ..
# 495   0   1
# 496   0   1
# 497   0   1
# 498   0   1
# 499   0   1
#
# [500 rows x 12 columns]
